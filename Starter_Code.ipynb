# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(["EIN", "NAME"], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
for column in application_df.columns:

    line_length = 32
    row_string = ""
    number = len(application_df[column].unique())

    number_length = len(str(number))
    column_length = len(column)
    spacing_length = line_length - (number_length + column_length)

    row_string += column
    for i in range(spacing_length):
        row_string += " "

    
    row_string += str(number)


    print(row_string)
# Out:
# APPLICATION_TYPE              17
# AFFILIATION                    6
# CLASSIFICATION                71
# USE_CASE                       5
# ORGANIZATION                   4
# STATUS                         2
# INCOME_AMT                     9
# SPECIAL_CONSIDERATIONS         2
# ASK_AMT                     8747
# IS_SUCCESSFUL                  2

# %%
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
apps = application_df["APPLICATION_TYPE"].value_counts()

application_types_to_replace = []
count_cutoff = 500

for index in application_df["APPLICATION_TYPE"].value_counts().index:
    if application_df["APPLICATION_TYPE"].value_counts()[index] < count_cutoff:
        application_types_to_replace.append(index)
print(application_types_to_replace)
# Out:
# ['T9', 'T13', 'T12', 'T2', 'T14', 'T25', 'T29', 'T15', 'T17']

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

apps = application_df["APPLICATION_TYPE"].value_counts()

application_types_to_replace = []
count_cutoff = 500

for index in application_df["APPLICATION_TYPE"].value_counts().index:
    if application_df["APPLICATION_TYPE"].value_counts()[index] < count_cutoff:
        application_types_to_replace.append(index)


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C3700        1
# C1570        1
# C2150        1
# C1732        1
# C2570        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df["CLASSIFICATION"].value_counts().loc[application_df["CLASSIFICATION"].value_counts() > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1237        9
# C1235        9
# C7210        7
# C2400        6
# C4100        6
# C1720        6
# C1600        5
# C1257        5
# C0           3
# C2710        3
# C1260        3
# C3200        2
# C1246        2
# C1267        2
# C1234        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_to_replace = []
count_cutoff = 1500

for index in application_df["CLASSIFICATION"].value_counts().index:
    if application_df["CLASSIFICATION"].value_counts()[index] < count_cutoff:
        classifications_to_replace.append(index)


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_numberic_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
target = application_numberic_df["IS_SUCCESSFUL"]
features = application_numberic_df.drop(["IS_SUCCESSFUL"], axis=1)


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=10)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu", input_dim=2))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid", input_dim=2))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 80)                3520
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                2430
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=200)
# Out:
# Epoch 1/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5693 - accuracy: 0.7226
# Epoch 2/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5546 - accuracy: 0.7300
# Epoch 3/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5528 - accuracy: 0.7313: 0s
# Epoch 4/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5504 - accuracy: 0.7317
# Epoch 5/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5491 - accuracy: 0.7324
# Epoch 6/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5489 - accuracy: 0.7324
# Epoch 7/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5476 - accuracy: 0.7339
# Epoch 8/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5478 - accuracy: 0.7337
# Epoch 9/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5462 - accuracy: 0.7356
# Epoch 10/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5457 - accuracy: 0.7366
# Epoch 11/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5450 - accuracy: 0.7356
# Epoch 12/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5455 - accuracy: 0.7353
# Epoch 13/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7343
# Epoch 14/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5447 - accuracy: 0.7354
# Epoch 15/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7361
# Epoch 16/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7357
# Epoch 17/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7373
# Epoch 18/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7372
# Epoch 19/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.7367
# Epoch 20/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5431 - accuracy: 0.7360
# Epoch 21/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7365: 0s - loss: 0.544
# Epoch 22/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7367
# Epoch 23/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5422 - accuracy: 0.7379
# Epoch 24/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7381
# Epoch 25/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5417 - accuracy: 0.7375
# Epoch 26/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7374
# Epoch 27/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5414 - accuracy: 0.7376
# Epoch 28/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5415 - accuracy: 0.7366
# Epoch 29/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5410 - accuracy: 0.7380
# Epoch 30/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7373
# Epoch 31/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5403 - accuracy: 0.7388
# Epoch 32/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7376
# Epoch 33/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7376
# Epoch 34/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5399 - accuracy: 0.7393
# Epoch 35/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5397 - accuracy: 0.7376
# Epoch 36/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5401 - accuracy: 0.7384
# Epoch 37/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5397 - accuracy: 0.7381
# Epoch 38/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7388
# Epoch 39/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7383
# Epoch 40/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7390
# Epoch 41/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5392 - accuracy: 0.7392
# Epoch 42/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5387 - accuracy: 0.7387
# Epoch 43/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5387 - accuracy: 0.7383
# Epoch 44/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7385
# Epoch 45/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5384 - accuracy: 0.7397
# Epoch 46/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5384 - accuracy: 0.7400
# Epoch 47/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5385 - accuracy: 0.7398
# Epoch 48/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5379 - accuracy: 0.7404
# Epoch 49/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5382 - accuracy: 0.7399
# Epoch 50/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7405
# Epoch 51/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5380 - accuracy: 0.7401
# Epoch 52/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5382 - accuracy: 0.7403
# Epoch 53/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7393
# Epoch 54/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7391
# Epoch 55/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7405: 0s - loss: 0.5378 - accuracy:
# Epoch 56/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5373 - accuracy: 0.7403
# Epoch 57/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5376 - accuracy: 0.7401
# Epoch 58/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5373 - accuracy: 0.7408: 0s - loss: 0.5352 -
# Epoch 59/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7411
# Epoch 60/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7402
# Epoch 61/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7402
# Epoch 62/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7401: 0s - loss: 0
# Epoch 63/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7396
# Epoch 64/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7399
# Epoch 65/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7402
# Epoch 66/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7402
# Epoch 67/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7394
# Epoch 68/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7401
# Epoch 69/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7404
# Epoch 70/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7406
# Epoch 71/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7404
# Epoch 72/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7404: 0s - loss: 0.5337 - accu
# Epoch 73/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7407
# Epoch 74/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5356 - accuracy: 0.7406
# Epoch 75/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5361 - accuracy: 0.7404
# Epoch 76/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7413
# Epoch 77/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7395
# Epoch 78/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5357 - accuracy: 0.7410
# Epoch 79/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7416
# Epoch 80/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5358 - accuracy: 0.7399
# Epoch 81/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7400
# Epoch 82/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7414
# Epoch 83/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5357 - accuracy: 0.7411: 0s - loss: 0.5361 - accuracy:
# Epoch 84/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7400
# Epoch 85/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5354 - accuracy: 0.7409
# Epoch 86/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5357 - accuracy: 0.7401
# Epoch 87/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7407
# Epoch 88/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5355 - accuracy: 0.7404
# Epoch 89/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7407
# Epoch 90/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5353 - accuracy: 0.7408
# Epoch 91/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5351 - accuracy: 0.7411
# Epoch 92/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7403
# Epoch 93/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5346 - accuracy: 0.7412
# Epoch 94/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7401
# Epoch 95/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7415
# Epoch 96/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7407
# Epoch 97/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7412
# Epoch 98/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7402
# Epoch 99/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7409
# Epoch 100/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7411
# Epoch 101/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7407: 0s - loss: 0.535
# Epoch 102/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5348 - accuracy: 0.7408
# Epoch 103/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5346 - accuracy: 0.7418
# Epoch 104/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7408
# Epoch 105/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7411
# Epoch 106/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5343 - accuracy: 0.7416
# Epoch 107/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7409: 0s - loss: 0.5345
# Epoch 108/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5347 - accuracy: 0.7420
# Epoch 109/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7414
# Epoch 110/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7417
# Epoch 111/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7413
# Epoch 112/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5343 - accuracy: 0.7420
# Epoch 113/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7409
# Epoch 114/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7418
# Epoch 115/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7410
# Epoch 116/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7413
# Epoch 117/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5346 - accuracy: 0.7410
# Epoch 118/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7418
# Epoch 119/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7421
# Epoch 120/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7407
# Epoch 121/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7414
# Epoch 122/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7407
# Epoch 123/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5338 - accuracy: 0.7409
# Epoch 124/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7413
# Epoch 125/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7416
# Epoch 126/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5340 - accuracy: 0.7416
# Epoch 127/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7418
# Epoch 128/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7424
# Epoch 129/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7410
# Epoch 130/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7417
# Epoch 131/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7412
# Epoch 132/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7413
# Epoch 133/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5339 - accuracy: 0.7413
# Epoch 134/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7417
# Epoch 135/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7419
# Epoch 136/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7417
# Epoch 137/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7417
# Epoch 138/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5333 - accuracy: 0.7413: 0s - loss: 0.5331 - ac
# Epoch 139/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7413
# Epoch 140/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5337 - accuracy: 0.7421
# Epoch 141/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7413
# Epoch 142/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5336 - accuracy: 0.7413
# Epoch 143/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7419: 0s - loss:
# Epoch 144/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7411
# Epoch 145/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5333 - accuracy: 0.7419
# Epoch 146/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7419
# Epoch 147/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7426
# Epoch 148/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7413
# Epoch 149/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7418
# Epoch 150/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7416
# Epoch 151/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5335 - accuracy: 0.7410
# Epoch 152/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7414
# Epoch 153/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7417
# Epoch 154/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7418
# Epoch 155/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7413
# Epoch 156/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5334 - accuracy: 0.7414
# Epoch 157/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7416
# Epoch 158/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7418
# Epoch 159/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5332 - accuracy: 0.7420
# Epoch 160/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5333 - accuracy: 0.7414
# Epoch 161/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7420
# Epoch 162/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7418
# Epoch 163/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7422: 0s - loss: 0.5335
# Epoch 164/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7429
# Epoch 165/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7422: 0s -
# Epoch 166/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5331 - accuracy: 0.7420
# Epoch 167/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7427
# Epoch 168/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5329 - accuracy: 0.7418
# Epoch 169/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7419
# Epoch 170/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7423
# Epoch 171/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7423
# Epoch 172/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7423
# Epoch 173/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5326 - accuracy: 0.7428
# Epoch 174/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7414
# Epoch 175/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7418
# Epoch 176/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7417
# Epoch 177/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7424
# Epoch 178/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7423
# Epoch 179/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7414
# Epoch 180/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7420
# Epoch 181/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7423: 0s - loss: 0.5
# Epoch 182/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7420
# Epoch 183/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7413
# Epoch 184/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7423
# Epoch 185/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7424
# Epoch 186/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7418
# Epoch 187/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7417
# Epoch 188/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7410
# Epoch 189/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5322 - accuracy: 0.7421
# Epoch 190/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7423
# Epoch 191/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7425
# Epoch 192/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7414
# Epoch 193/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7419
# Epoch 194/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5321 - accuracy: 0.7415
# Epoch 195/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7421
# Epoch 196/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7432
# Epoch 197/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7424
# Epoch 198/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5320 - accuracy: 0.7418
# Epoch 199/200
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7424
# Epoch 200/200
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7418

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5673 - accuracy: 0.7285
# Loss: 0.5673232078552246, Accuracy: 0.7285131216049194

# %%
# Export our model to HDF5 file
nn.save_weights("application.hdf5")
